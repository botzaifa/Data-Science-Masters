# %% [markdown]
# # Assignment - 21 (Image Scraping)

# %% [markdown]
# ### Q1. Write a python program to extract the video URL of the first five videos.

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

handle = "PW-Foundation" 

url = f"https://www.youtube.com/@{handle}/videos"


options = webdriver.ChromeOptions()
options.add_argument("--headless")

driver = webdriver.Chrome(options=options)
driver.get(url)

driver.execute_script("window.scrollTo(0,500)","")  

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

for i in range(5):
    print("https://www.youtube.com" + str((soup.find_all("a", {"id": "video-title-link"}))[i].get("href")))
# Out:
# https://www.youtube.com/watch?v=5bRZ5yYF5Mw
# https://www.youtube.com/watch?v=kGGlONm9GW0
# https://www.youtube.com/watch?v=aBLasjkB4UU
# https://www.youtube.com/watch?v=fXDjD7Nd1OA
# https://www.youtube.com/watch?v=jyXIhE28Enc

# %% [markdown]
# ### Q2. Write a python program to extract the URL of the video thumbnails of the first five videos.

# %%
options = webdriver.ChromeOptions()
options.add_argument("--headless")

driver = webdriver.Chrome(options=options)
driver.get(url)

driver.execute_script("window.scrollTo(0,500)","")  

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

for i in range(5):
    print((soup.find_all("img", {"class": "yt-core-image--fill-parent-height"}))[i].get("src")[0:48])
# Out:
# https://i.ytimg.com/vi/5bRZ5yYF5Mw/hqdefault.jpg
# https://i.ytimg.com/vi/kGGlONm9GW0/hqdefault.jpg
# https://i.ytimg.com/vi/aBLasjkB4UU/hqdefault.jpg
# https://i.ytimg.com/vi/fXDjD7Nd1OA/hqdefault.jpg
# https://i.ytimg.com/vi/jyXIhE28Enc/hqdefault.jpg

# %% [markdown]
# ### Q3. Write a python program to extract the title of the first five videos.

# %%
options = webdriver.ChromeOptions()
options.add_argument("--headless")

driver = webdriver.Chrome(options=options)
driver.get(url)

driver.execute_script("window.scrollTo(0,500)","")  

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

for i in range(5):
    print((soup.find_all("a", {"id": "video-title-link"}))[i].text)
# Out:
# Arjuna JEE Vs Arjuna NEET Rivalry is Back 🔥😎 #PW #Shorts #ArjunaBatch
# Arjuna JEE Vs Arjuna NEET Maha Sangram 🔥🔥 #PW #Shorts #ArjunaBatch
# क्या आपको भी इंतज़ार है UDAAN Batch Start होने का ⁉ #PW #Shorts #Udaan2025
# GYAAN ka महा - संग्राम 🔥 Arjuna JEE VS Arjuna NEET | Who will WIN?
# UDAAN 2.0 & NEEV 2.0 Live Orientation Session For Class 10th & 9th Students 🎯

# %% [markdown]
# ### Q.4 Write a python program to extract the number of views of the first five videos.

# %%
options = webdriver.ChromeOptions()
options.add_argument("--headless")

driver = webdriver.Chrome(options=options)
driver.get(url)

driver.execute_script("window.scrollTo(0,500)","")  

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

for i in range(5):
    print((soup.find_all("div", {"id": "metadata"}))[i].find_all("span")[0].text)
# Out:
# Video ID: fQYvvorBTvU, Views: 1854
# Video ID: 6qKnuxWBHxw, Views: 5675
# Video ID: sHYuGAztlo4, Views: 3121
# Video ID: I1OdqS8zyCU, Views: 0
# Video ID: 5d1mZAVs0pE, Views: 0

# %% [markdown]
# ### Q5. Write a python program to extract the time of posting of video for the first five videos.

# %%
options = webdriver.ChromeOptions()
options.add_argument("--headless")

driver = webdriver.Chrome(options=options)
driver.get(url)

driver.execute_script("window.scrollTo(0,500)","")  

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

for i in range(5):
    print((soup.find_all("div", {"id": "metadata"}))[i].find_all("span")[1].text)
# Out:
# 7 days ago
# 10 days ago
# 2 weeks ago
# 2 weeks ago
# 2 weeks ago

# %% [markdown]
# ## Saving all the Scraped Data in to a CSV file:

# %%
import pandas as pd
scrapes = []
for i in range(5):
    title = (soup.find_all("a", {"id": "video-title-link"}))[i].text
#    view = (soup.find_all("div", {"id": "metadata"}))[i].find_all("span")[1].text
    upload = (soup.find_all("div", {"id": "metadata"}))[i].find_all("span")[1].text
    video_link = "https://www.youtube.com" + str((soup.find_all("a", {"id": "video-title-link"}))[i].get("href"))
    thumbnail_link = (soup.find_all("img", {"class": "yt-core-image--fill-parent-height"}))[i].get("src")[0:48]
    
    data = {"Title": title,"Views": view,"Upload": upload,"Video Link": video_link,"Thumbnail Link": thumbnail_link}
        
    scrapes.append(data)
csv = pd.DataFrame(scrapes)
csv.to_csv(f"{handle}.csv", index=False)
# Out:
# Data saved to video_details.csv

# %% [markdown]
# ## Screen Shots of the saved CSV File:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
