# %% [markdown]
# # Assignment (2nd March) : Visualization (Matplotlib)

# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# **ANS:** Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. It is particularly well-suited for generating plots and graphs, and is widely used in data analysis, scientific computing, and data visualization tasks.
#
# Matplotlib is used because it provides a versatile and powerful toolset for producing a wide variety of plots and visualizations.
#
# Some plots that can be plotted using the Pyplot module of Matplotlib are as follows:
#
# 1. Line Plot
# 2. Bar Plot
# 3. Histogram
# 4. Scatter Plot
# 5. Pie Chart

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# (Note: Also add title, xlabel, and ylabel to the plot.)

# %% [markdown]
# **ANS:** A scatter plot is a type of data visualization that displays individual data points on a two-dimensional plane. Each point represents the values of two variables, with one variable plotted along the x-axis and the other plotted along the y-axis. Scatter plots are commonly used to observe relationships, correlations, and distributions of the data points.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x, y)

plt.title("Scatter Plot of Generated Data")
plt.xlabel("X values")
plt.ylabel("Y values")

plt.show()

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function. Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# **ANS:** The `subplot()` function in Matplotlib is used to create multiple plots within a single figure. This is useful for comparing different visualizations side by side or in a grid layout. It allows you to organize multiple plots in rows and columns, making it easier to interpret and compare data.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])


plt.figure(figsize=(10, 10))

# Line plot 1
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title("Line Plot 1")
plt.xlabel("X values")
plt.ylabel("Y values")

# Line plot 2
plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title("Line Plot 2")
plt.xlabel("X values")
plt.ylabel("Y values")

# Line plot 3
plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title("Line Plot 3")
plt.xlabel("X values")
plt.ylabel("Y values")

# Line plot 4
plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title("Line Plot 4")
plt.xlabel("X values")
plt.ylabel("Y values")

# Adjust layout to prevent overlap
plt.tight_layout()

# Show plots
plt.show()

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# **ANS:** A bar plot (or bar chart) is a type of chart that presents categorical data with rectangular bars. The length or height of each bar is proportional to the value it represents. Bar plots are used to compare different categories or groups. They are particularly useful for highlighting differences in size, frequency, or other metrics among categories.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.figure(figsize=(12, 6))

# Bar Plot
plt.subplot(1, 2, 1)
plt.bar(company, profit, color='skyblue')
plt.title("Bar Plot of Company Profits")
plt.xlabel("Company")
plt.ylabel("Profit (in millions)")

# Horizontal Bar Plot
plt.subplot(1, 2, 2)
plt.barh(company, profit, color='lightgreen')
plt.title("Horizontal Bar Plot of Company Profits")
plt.xlabel("Profit (in millions)")
plt.ylabel("Company")

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# **ANS:** A box plot is a standardized way of displaying the distribution of data based on a five-number summary: minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum. It visually depicts the variability and skewness of the data and identifies outliers. Box plots are used for several reasons such as:
#
# 1. Summarizing Data
# 2. Identifying Outliers
# 3. Comparing Distributions
# 4. Detecting Skewness
# 5. Visualizing Spread and Variability

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.figure(figsize=(8, 6))

plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'])

plt.title('Box Plot of box1 and box2')
plt.xlabel('Box')
plt.ylabel('Values')

plt.show()
